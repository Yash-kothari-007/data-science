# %%
import pandas as pd

# %%
data_one= {
  "id": 1,
  "title": "Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops",
  "price": 109.95,
  "description": "Your perfect pack for everyday use and walks in the forest.",
  "category": "men's clothing",
  "rating":  3.9
}
data_two={
  "id": 2,
  "title": "Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops",
  "price": 190.95,
  "description": "Your perfect pack for everyday use and walks in the forest.",
  "category": "men's clothing",
  "rating": 4.2,
}
data_three={
  "id": 2,
  "title": "Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops",
  "price": 10.95,
  "description": "Your perfect pack for everyday use and walks in the forest.",
  "category": "men's clothing",
  "rating": 4.5,
}

# %%
lis =[]
lis.append(data_one)
lis.append(data_two)
lis.append(data_three)

# %%
df =pd.DataFrame(lis)
df
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  190.95
# 2   2  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...   10.95
#
#                                          description        category  rating
# 0  Your perfect pack for everyday use and walks i...  men's clothing     3.9
# 1  Your perfect pack for everyday use and walks i...  men's clothing     4.2
# 2  Your perfect pack for everyday use and walks i...  men's clothing     4.5
