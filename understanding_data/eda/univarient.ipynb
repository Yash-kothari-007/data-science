# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../archive/tested.csv')
print(df.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.countplot(x="Pclass", data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
print(df[df["Pclass"]==3].count())
# Out:
# PassengerId    218
# Survived       218
# Pclass         218
# Name           218
# Sex            218
# Age            146
# SibSp          218
# Parch          218
# Ticket         218
# Fare           217
# Cabin            4
# Embarked       218
# dtype: int64

# %%
print(df["Survived"].value_counts())
sns.countplot(x="Survived",data=df)
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df["Survived"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: >

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct='.%2f')
# Out:
# <Axes: >

# %%
df["Embarked"].value_counts().plot(kind="pie",autopct=".%2f")
# Out:
# <Axes: >

# %%
print(plt.hist(df["Age"])) # by default value is 10
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]), array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#        60.834, 68.417, 76.   ]), <BarContainer object of 10 artists>)

# %%
plt.hist(df["Age"],bins=5)
# Out:
# (array([ 32., 168.,  80.,  42.,  10.]),
#  array([ 0.17 , 15.336, 30.502, 45.668, 60.834, 76.   ]),
#  <BarContainer object of 5 artists>)

# %%
sns.displot(df["Age"],kde=True)

# %%
sns.kdeplot(df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(df["Fare"])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.boxplot(df["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
df["Fare"].skew()
# Out:
# np.float64(3.6872133081121405)

# %%
df["Fare"].std()
# Out:
# np.float64(55.907576179973844)
